# %% [markdown]
# ## Technical Signal

# %%
# %matplotlib inline
import tushare as ts
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
import tushare as ts
from techFun import *

# %%
df_sh = ts.get_hist_data('sh',start='2015-12-05',end='2016-12-23')
df_ldkg = ts.get_hist_data('600606',start='2015-12-05',end='2016-12-23')

# %%
df_ldkg['close'].shape
# Out:
# (256,)

# %%
import techFun
techFun.MA(range(9),2)
techFun.VOL(range(9),2)
# Out:
# [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, -1]

# %%
df_m =pd.merge(df_ldkg,df_sh
         ,left_index=True,right_index=True,how='right')#merge by index
df_m.iloc[0:5]
# Out:
#             open_x  high_x  close_x  low_x   volume_x  price_change_x  \
# date
# 2016-12-23    9.01    9.02     8.87   8.83  530662.25           -0.14
# 2016-12-22    9.06    9.06     9.01   8.97  322022.34           -0.05
# 2016-12-21    9.03    9.06     9.06   9.01  354934.44            0.04
# 2016-12-20    9.03    9.04     9.02   8.95  299407.62            0.00
# 2016-12-19    9.08    9.11     9.02   8.99  360903.69           -0.10
#
#             p_change_x  ma5_x  ma10_x  ma20_x     ...        low_y  \
# date                                              ...
# 2016-12-23       -1.55  8.996   9.016   9.300     ...      3103.75
# 2016-12-22       -0.55  9.046   9.068   9.345     ...      3126.89
# 2016-12-21        0.44  9.046   9.102   9.384     ...      3107.24
# 2016-12-20        0.00  9.026   9.146   9.422     ...      3084.80
# 2016-12-19       -1.10  9.036   9.189   9.429     ...      3110.08
#
#               volume_y  price_change_y  p_change_y     ma5_y    ma10_y  \
# date
# 2016-12-23  1661767.75          -29.41       -0.94  3121.620  3129.730
# 2016-12-22  1678049.88            2.13        0.07  3124.186  3142.003
# 2016-12-21  1867066.12           34.55        1.11  3119.810  3149.584
# 2016-12-20  1574267.62          -15.20       -0.49  3120.430  3158.065
# 2016-12-19  1541697.12           -4.90       -0.16  3130.862  3167.742
#
#               ma20_y     v_ma5_y    v_ma10_y    v_ma20_y
# date
# 2016-12-23  3184.963  1664569.70  1848496.01  2058088.36
# 2016-12-22  3192.552  1662193.55  1886343.19  2091960.78
# 2016-12-21  3197.661  1706564.82  1889248.37  2124220.54
# 2016-12-20  3202.847  1735869.37  1871614.61  2155847.04
# 2016-12-19  3210.120  1791344.85  1871760.54  2207949.43
#
# [5 rows x 27 columns]

# %%
len(techFun.MA(df_ldkg['close'].values, 5))
# Out:
# 256

# %%
len(techFun.VOL(df_ldkg['close'].values,5))
# Out:
# 256

# %%
sig=pd.DataFrame({'close':df_ldkg['close'].values,
              'ma':techFun.MA(df_ldkg['close'].values, 5),
              'vol':techFun.VOL(df_ldkg['close'].values,5),
                 'time':df_ldkg.index.values})
sig = sig.set_index('time')

# %%
sig
# Out:
#             close      ma       vol
# time
# 2016-12-23   8.87   8.996  0.065299
# 2016-12-22   9.01   9.046  0.040792
# 2016-12-21   9.06   9.046  0.040792
# 2016-12-20   9.02   9.026  0.052000
# 2016-12-19   9.02   9.036  0.054626
# 2016-12-16   9.12   9.036  0.054626
# 2016-12-15   9.01   9.090  0.154013
# 2016-12-14   8.96   9.158  0.177020
# 2016-12-13   9.07   9.266  0.187681
# 2016-12-12   9.02   9.342  0.168926
# 2016-12-09   9.39   9.442  0.064312
# 2016-12-08   9.35   9.502  0.110887
# 2016-12-07   9.50   9.644  0.223123
# 2016-12-06   9.45   9.660  0.214942
# 2016-12-05   9.52   9.678  0.199840
# 2016-12-02   9.69   9.724  0.184022
# 2016-12-01  10.06   9.740  0.183848
# 2016-11-30   9.58   9.688  0.106471
# 2016-11-29   9.54   9.734  0.099318
# 2016-11-28   9.75   9.660  0.245927
# 2016-11-25   9.77   9.538  0.313139
# 2016-11-24   9.80   9.410  0.322800
# 2016-11-23   9.81   9.284  0.263484
# 2016-11-22   9.17   9.160  0.021909
