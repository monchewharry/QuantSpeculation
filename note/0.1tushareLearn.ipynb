# %% [markdown]
# reference: <http://tushare.org/trading.html#id4>

# %%
import tushare as ts

# %% [markdown]
# ## real time

# %%
ts.get_index()
# Out:
#       code    name  change        open    preclose       close        high  \
# 0   000001    上证指数   -0.91   3115.8984   3118.0846   3089.7147   3117.0145
# 1   000002    Ａ股指数   -0.91   3262.3875   3264.6737   3234.9636   3263.5600
# 2   000003    Ｂ股指数   -0.86    344.3434    344.6643    341.7069    344.4268
# 3   000008    综合指数   -1.08   2712.0084   2712.7597   2683.5440   2714.1952
# 4   000009   上证380   -0.71   5570.3096   5575.0965   5535.3049   5570.8037
# 5   000010   上证180   -1.06   7249.2463   7248.1404   7171.1606   7252.3828
# 6   000011    基金指数   -0.46   5737.1814   5737.6042   5711.1183   5738.5728
# 7   000012    国债指数   -0.07    159.5868    159.5738    159.4644    159.6271
# 8   000016    上证50   -1.06   2293.3996   2291.3842   2267.1660   2295.1135
# 9   000017     新综指   -0.91   2630.1947   2631.9883   2608.0692   2631.1407
# 10  000300   沪深300   -1.02   3328.2985   3328.9827   3295.0074   3329.1022
# ...

# %%
# ts.get_today_all()
df = ts.get_realtime_quotes('600606') #Single stock symbol
df[['code','name','price','bid','ask','volume','amount','time']]
# Out:
#      code  name  price    bid    ask    volume         amount      time
# 0  600606  绿地控股  8.970  8.970  8.980  26405158  237130580.000  14:52:10

# %%
#上证指数 深圳成指 沪深300指数 上证50 中小板 创业板
ts.get_realtime_quotes(['sh','sz','hs300','sz50','zxb','cyb'])
# Out:
#     name       open  pre_close      price       high        low    bid    ask  \
# 0   上证指数  3115.8984  3118.0846  3092.4605  3117.0145  3084.7997      0      0
# 1   深证成指  10275.439  10283.164  10230.734  10276.628  10204.019  0.000  0.000
# 2  沪深300   3328.299   3328.983   3296.833   3329.102   3289.268  0.000  0.000
# 3   上证50  2293.3996  2291.3842  2268.9454  2295.1135  2262.8781      0      0
# 4   中小板指   6513.753   6514.097   6491.317   6517.443   6472.095  0.000  0.000
# 5   创业板指   1981.693   1980.410   1980.116   1989.986   1974.928  0.000  0.000
#
#         volume            amount   ...     a2_p a3_v   a3_p a4_v   a4_p a5_v  \
# 0    148536315      162031460781   ...        0           0           0
# 1  14550322625  204328530849.134   ...    0.000       0.000       0.000
# 2   8254120000   83607411476.000   ...    0.000       0.000       0.000
# 3     27810659       27023777965   ...        0           0           0
# ...

# %%
#或者混搭
ts.get_realtime_quotes(['sh','600848'])
# Out:
#    name       open  pre_close      price       high        low     bid  \
# 0  上证指数  3115.8984  3118.0846  3092.0580  3117.0145  3084.7997       0
# 1  上海临港     18.450     18.530     18.340     18.480     18.200  18.330
#
#       ask     volume        amount   ...      a2_p a3_v    a3_p a4_v    a4_p  \
# 0       0  148341753  161804867700   ...         0            0            0
# 1  18.340    2707800  49656094.000   ...    18.350  105  18.360   90  18.370
#
#   a5_v    a5_p        date      time    code
# 0            0  2016-12-20  14:54:01  000001
# 1  153  18.380  2016-12-20  14:54:05  600848
#
# [2 rows x 33 columns]

# %%
df = ts.get_realtime_quotes('sh')
if df['price'][0] > df['low'][0]:
    print '\a'##make a sound

# %%
df
# Out:
#    name       open  pre_close      price       high        low bid ask  \
# 0  上证指数  3115.8984  3118.0846  3102.8759  3117.0145  3084.7997   0   0
#
#       volume        amount   ...   a2_p a3_v a3_p a4_v a4_p a5_v a5_p  \
# 0  157426759  171611881109   ...      0         0         0         0
#
#          date      time    code
# 0  2016-12-20  15:01:03  000001
#
# [1 rows x 33 columns]

# %% [markdown]
# ## historical data

# %%
a=ts.get_hist_data('600848',start='2016-12-05',end='2016-12-20')
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# date
# 2016-12-20  18.45  18.48  18.38  18.20   28583.00         -0.15     -0.81
# 2016-12-19  18.50  18.68  18.53  18.35   30877.32          0.05      0.27
# 2016-12-16  18.53  18.85  18.48  18.45   47045.17          0.00      0.00
# 2016-12-15  17.98  18.86  18.48  17.88   60191.69          0.44      2.44
# 2016-12-14  18.11  18.50  18.04  17.55   81916.83         -0.40     -2.17
# 2016-12-13  19.04  19.15  18.44  17.18  131585.48         -0.58     -3.05
# 2016-12-12  19.48  19.92  19.02  18.98   88336.21         -0.38     -1.96
# 2016-12-09  20.91  20.99  19.40  19.37  120205.35         -1.51     -7.22
# 2016-12-08  21.30  21.39  20.91  20.85   40095.18         -0.39     -1.83
# 2016-12-07  21.14  21.32  21.30  20.82   25909.87          0.32      1.52
# 2016-12-06  21.18  21.38  20.98  20.85   41620.73         -0.22     -1.04
# 2016-12-05  20.85  21.38  21.20  20.82   39028.21          0.14      0.67
#
# ...

# %%
a=ts.get_hist_data('600848',start='2016-12-05',end='2016-12-20')
a.columns
# Out:
# Index([u'open', u'high', u'close', u'low', u'volume', u'price_change',
#        u'p_change', u'ma5', u'ma10', u'ma20', u'v_ma5', u'v_ma10', u'v_ma20',
#        u'turnover'],
#       dtype='object')

# %%
type(a.index)
# Out:
# pandas.tseries.index.DatetimeIndex

# %% [markdown]
# ## tick data

# %%
ts.get_tick_data('600606',date='2014-01-09')
# Out:
#        time  price  change  volume  amount type
# 0  15:00:10   5.23    5.23       0       0   卖盘

# %% [markdown]
# ## Huge transaction

# %%
df=ts.get_sina_dd('601668', date='2016-12-20',vol=15000) #默认400手
df
# Out:
#      code  name      time  price   volume  preprice type
# 0  601668  中国建筑  14:58:02   8.74  1530400      8.73   买盘
# 1  601668  中国建筑  14:57:38   8.73  1724700      8.73   卖盘
# 2  601668  中国建筑  14:53:31   8.70  2293700      8.67   买盘
# 3  601668  中国建筑  14:53:07   8.66  1789894      8.64   买盘
# 4  601668  中国建筑  14:25:41   8.61  1809500      8.60   买盘
# 5  601668  中国建筑  09:45:30   8.83  1759500      8.84   卖盘
# 6  601668  中国建筑  09:30:09   8.70  1834600      8.72   卖盘
# 7  601668  中国建筑  09:30:04   8.72  1506000      8.71   买盘
# 8  601668  中国建筑  09:25:01   8.69  4929900      0.00   买盘

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['price'][0]
# Out:
# 8.7400000000000002

# %%
df['price']
# Out:
# 0    8.74
# 1    8.73
# 2    8.70
# 3    8.66
# 4    8.61
# 5    8.83
# 6    8.70
# 7    8.72
# 8    8.69
# Name: price, dtype: float64

# %% [markdown]
# ## 保存数据

# %%
df = ts.get_hist_data('601668')
df.to_csv('./601668.csv')
df.to_csv('./601668OHLC.csv',columns=['open','high','low','close'])

# %%
df.to_hdf('./hdf.h5','601668stock')
